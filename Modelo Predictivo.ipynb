# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %% [markdown]
# # Inputs + Outputs historicos

# %% [markdown]
# ### Formato en el que fué dejado el archivo Excel que contiene el histórico

# %%
dataframe = pd.read_excel(r"Historico.xlsx")
dataframe.head()
# Out:
#    Fase  Banco  Tipo de tronadura  Tipo Material   M  Dominio Estructural  \
# 0     1   2930                  7              9  13                   19
# 1     2   2990                  7              9  13                   19
# 2     2   2930                  7              9  13                   19
# 3     2   2990                  7              9  13                   19
# 4     3   3575                  8              9  14                   20
#
#    Diámetro    B    S  Ms1  ...   P10   P20   P30   P40   P50   P60   P70  \
# 0        24  6.5  6.5   11  ...  0.12  0.55  0.87  1.46  2.60  3.94  5.12
# 1        24  6.5  6.5   11  ...  0.24  0.51  0.83  1.46  2.52  3.62  4.88
# 2        24  6.5  6.5   11  ...  0.39  0.79  1.26  1.85  2.72  3.62  4.80
# 3        24  6.5  8.0    5  ...  0.16  0.67  1.10  1.69  2.60  3.66  4.72
# 4        24  7.0  7.0    5  ...  0.59  0.79  1.02  1.34  1.89  2.91  4.06
#
#     P80   P90   P100
# 0  6.50  9.37  15.08
# 1  6.34  8.46  13.54
# ...

# %% [markdown]
# # Inputs de entrenamiento

# %% [markdown]
# ### Formato en el que fué dejado el archivo que contiene los datos para entrenar

# %%
dataframe = pd.read_excel(r"TrainingData.xlsx")
dataframe.head()
# Out:
#    Fase  Banco  Tipo de tronadura  Tipo Material   M  Dominio Estructural  \
# 0     1   2930                  7              9  13                   19
# 1     2   2990                  7              9  13                   19
# 2     2   2930                  7              9  13                   19
# 3     2   2990                  7              9  13                   19
# 4     3   3575                  8              9  14                   20
#
#    Diámetro    B    S  Ms1  Ms2   Fc  Tipo Explosivo
# 0        24  6.5  6.5   11  105  498              99
# 1        24  6.5  6.5   11  105  424              99
# 2        24  6.5  6.5   11  105  424              99
# 3        24  6.5  8.0    5   87  385              99
# 4        24  7.0  7.0    5   87  507             100

# %% [markdown]
# # Outputs de entrenamiento

# %% [markdown]
# ### Formato en el que fué dejado el archivo que contiene los resultados de los datos a entrenar

# %%
dataframe = pd.read_excel(r"TrainingScores.xlsx")
dataframe.head()
# Out:
#     P10   P20   P30   P40   P50   P60   P70   P80   P90   P100
# 0  0.12  0.55  0.87  1.46  2.60  3.94  5.12  6.50  9.37  15.08
# 1  0.24  0.51  0.83  1.46  2.52  3.62  4.88  6.34  8.46  13.54
# 2  0.39  0.79  1.26  1.85  2.72  3.62  4.80  6.38  9.25  14.61
# 3  0.16  0.67  1.10  1.69  2.60  3.66  4.72  6.22  8.15  16.46
# 4  0.59  0.79  1.02  1.34  1.89  2.91  4.06  4.88  6.38  11.46

# %% [markdown]
# # inputs de predicción

# %% [markdown]
# ### Formato en el que fué dejado el archivo con los inputs a predecir

# %%
dataframe = pd.read_excel(r"Datos_de_prueba.xlsx")
dataframe.head()
# Out:
#    Fase  Banco  Tipo de tronadura  Tipo Material   M  Dominio Estructural  \
# 0     3   3590                  7             10  14                   20
# 1     3   3485                  8              9  16                   20
# 2     3   3485                  8             10  15                   20
# 3     3   3485                  8             10  15                   20
# 4     3   3485                  8             10  15                   20
#
#    Diámetro    B   S  Ms1  Ms2   Fc  Tipo Explosivo
# 0        24  9.0  11   17  120  245              99
# 1        25  9.0  11    4   30  204             104
# 2        25  9.0  11    4   30  205             104
# 3        25  9.0  11    4   30  205             104
# 4        25  9.0  11    4   30  298             104

# %% [markdown]
# # Outputs de predicción

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()]

trainingData    = pd.read_excel(r"TrainingData.xlsx")
trainingScores  = pd.read_excel(r"TrainingScoresP10.xlsx")
predictionData  = pd.read_excel(r"Datos_de_prueba.xlsx")

for item in classifiers:
    print(item)
    clf = item
    clf.fit(trainingData, trainingScores)
    print(clf.predict(predictionData),'\n')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [0.54927576 0.54873493 0.5231648  0.5231648  0.54927576 0.5231648
#  0.5231648  0.5231648  0.5231648  0.54927576 0.54927576 0.54927576
#  0.54927576 0.54927576 0.52368891 0.53697278 0.53598904 0.5492763
# ...

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()]

trainingData    = pd.read_excel(r"TrainingData.xlsx")
trainingScores  = pd.read_excel(r"TrainingScoresP20.xlsx")
predictionData  = pd.read_excel(r"Datos_de_prueba.xlsx")

for item in classifiers:
    print(item)
    clf = item
    clf.fit(trainingData, trainingScores)
    print(clf.predict(predictionData),'\n')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [0.946129   0.94005397 0.90069922 0.90069922 0.946129   0.90069922
#  0.90069922 0.90069922 0.90069922 0.946129   0.946129   0.946129
#  0.946129   0.946129   0.90322759 0.91859667 0.91639521 0.94612956
# ...

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()]

trainingData    = pd.read_excel(r"TrainingData.xlsx")
trainingScores  = pd.read_excel(r"TrainingScoresP30.xlsx")
predictionData  = pd.read_excel(r"Datos_de_prueba.xlsx")

for item in classifiers:
    print(item)
    clf = item
    clf.fit(trainingData, trainingScores)
    print(clf.predict(predictionData),'\n')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [1.38979544 1.35971764 1.31277656 1.31277656 1.38979544 1.31277656
#  1.31277656 1.31277656 1.31277656 1.38979544 1.38979544 1.38979544
#  1.38979544 1.38979544 1.3331957  1.35608364 1.35338808 1.38979566
# ...

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()]

trainingData    = pd.read_excel(r"TrainingData.xlsx")
trainingScores  = pd.read_excel(r"TrainingScoresP40.xlsx")
predictionData  = pd.read_excel(r"Datos_de_prueba.xlsx")

for item in classifiers:
    print(item)
    clf = item
    clf.fit(trainingData, trainingScores)
    print(clf.predict(predictionData),'\n')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [1.9145962  1.8865123  1.8311378  1.8311378  1.9145962  1.8311378
#  1.8311378  1.8311378  1.8311378  1.9145962  1.9145962  1.9145962
#  1.9145962  1.9145962  1.85816256 1.87432905 1.87110932 1.91459625
# ...

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()]

trainingData    = pd.read_excel(r"TrainingData.xlsx")
trainingScores  = pd.read_excel(r"TrainingScoresP50.xlsx")
predictionData  = pd.read_excel(r"Datos_de_prueba.xlsx")

for item in classifiers:
    print(item)
    clf = item
    clf.fit(trainingData, trainingScores)
    print(clf.predict(predictionData),'\n')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [2.53915911 2.48751793 2.44221207 2.44221207 2.53915911 2.44221207
#  2.44221207 2.44221207 2.44221207 2.53915911 2.53915911 2.53915911
#  2.53915911 2.53915911 2.48240279 2.47029369 2.46478728 2.53915917
# ...

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()]

trainingData    = pd.read_excel(r"TrainingData.xlsx")
trainingScores  = pd.read_excel(r"TrainingScoresP60.xlsx")
predictionData  = pd.read_excel(r"Datos_de_prueba.xlsx")

for item in classifiers:
    print(item)
    clf = item
    clf.fit(trainingData, trainingScores)
    print(clf.predict(predictionData),'\n')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [3.26955965 3.20252426 3.15059428 3.15059428 3.26955965 3.15059428
#  3.15059428 3.15059428 3.15059428 3.26955965 3.26955965 3.26955965
#  3.26955965 3.26955965 3.2102784  3.17332412 3.16562922 3.26955959
# ...

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()]

trainingData    = pd.read_excel(r"TrainingData.xlsx")
trainingScores  = pd.read_excel(r"TrainingScoresP70.xlsx")
predictionData  = pd.read_excel(r"Datos_de_prueba.xlsx")

for item in classifiers:
    print(item)
    clf = item
    clf.fit(trainingData, trainingScores)
    print(clf.predict(predictionData),'\n')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [4.11023675 4.00890313 3.96849304 3.96849304 4.11023675 3.96849304
#  3.96849304 3.96849304 3.96849304 4.11023675 4.11023675 4.11023675
#  4.11023675 4.11023675 4.03818304 3.9925271  3.98311516 4.11023663
# ...

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()]

trainingData    = pd.read_excel(r"TrainingData.xlsx")
trainingScores  = pd.read_excel(r"TrainingScoresP80.xlsx")
predictionData  = pd.read_excel(r"Datos_de_prueba.xlsx")

for item in classifiers:
    print(item)
    clf = item
    clf.fit(trainingData, trainingScores)
    print(clf.predict(predictionData),'\n')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [5.16493293 5.03125897 4.99813618 4.99813618 5.16493293 4.99813618
#  4.99813618 4.99813618 4.99813618 5.16493293 5.16493293 5.16493293
#  5.16493293 5.16493293 5.07779473 5.00879566 4.99631108 5.16493217
# ...

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()]

trainingData    = pd.read_excel(r"TrainingData.xlsx")
trainingScores  = pd.read_excel(r"TrainingScoresP90.xlsx")
predictionData  = pd.read_excel(r"Datos_de_prueba.xlsx")

for item in classifiers:
    print(item)
    clf = item
    clf.fit(trainingData, trainingScores)
    print(clf.predict(predictionData),'\n')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [6.65901653 6.49435468 6.48308397 6.48308397 6.65901653 6.48308397
#  6.48308397 6.48308397 6.48308397 6.65901653 6.65901653 6.65901653
#  6.65901653 6.65901653 6.54769408 6.46857719 6.45334985 6.65901497
# ...

# %%
import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()]

trainingData    = pd.read_excel(r"TrainingData.xlsx")
trainingScores  = pd.read_excel(r"TrainingScoresP100.xlsx")
predictionData  = pd.read_excel(r"Datos_de_prueba.xlsx")

for item in classifiers:
    print(item)
    clf = item
    clf.fit(trainingData, trainingScores)
    print(clf.predict(predictionData),'\n')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [10.62768368 10.38080479 10.32357593 10.32357593 10.62768368 10.32357593
#  10.32357593 10.32357593 10.32357593 10.62768368 10.62768368 10.62768368
#  10.62768368 10.62768368 10.47972838 10.37705327 10.35701312 10.6276872
# ...

# %% [markdown]
# # Descartar resultados

# %%
dataframe = pd.read_excel(r"Historico.xlsx")
dataframe.describe( percentiles=[0.5])
# Out:
#               Fase        Banco  Tipo de tronadura  Tipo Material  \
# count  1959.000000  1959.000000        1959.000000    1959.000000
# mean      2.497703  3145.972435           7.860643       9.459418
# std       0.684626   281.599539           0.346407       0.542628
# min       1.000000  2810.000000           7.000000       9.000000
# 50%       2.000000  2960.000000           8.000000       9.000000
# max       6.000000  3875.000000           8.000000      12.000000
#
#                  M  Dominio Estructural     Diámetro            B  \
# count  1959.000000          1959.000000  1959.000000  1959.000000
# mean     13.915263            19.735579    24.891782     9.050281
# std       1.256227             0.585416     0.373440     2.778400
# min      13.000000            19.000000    24.000000     4.000000
# 50%      13.000000            20.000000    25.000000     7.000000
# max      18.000000            23.000000    28.000000    18.000000
#
# ...

# %% [markdown]
# ### Analizando los resultados obtenidos y comparandolos con los datos reales se descartaron los siguientes clasificadores

# %% [markdown]
# * SGDRegressor
# * ARDRegression
# * LassoLars
# * PassiveAggressiveRegressor
